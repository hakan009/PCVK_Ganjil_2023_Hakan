# %% [markdown]
# <a href="https://colab.research.google.com/github/hakan009/PCVK_Ganjil_2023_Hakan/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#mount drive
from google.colab import drive


drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
path = '/content/drive/MyDrive/PCVK/catto.jfif'
img = cv.imread (path)
plt.imshow(img)
plt.show()
